# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('Dataset3.csv',sep=';',index_col='No')

# %%
train.head()
# Out:
#     Country Level of development European Union Membership Currency  \
# No
# 4   Austria            Developed                    Member     Euro
# 6   Belgium            Developed                    Member     Euro
# 17  Estonia            Developed                    Member     Euro
# 18  Finland            Developed                    Member     Euro
# 19   France            Developed                    Member     Euro
#
#     Women Entrepreneurship Index  Entrepreneurship Index  Inflation rate  \
# No
# 4                           54.9                    64.9            0.90
# 6                           63.6                    65.5            0.60
# 17                          55.4                    60.2           -0.88
# 18                          66.4                    65.7           -0.20
# 19                          68.8                    67.3            0.00
#
#     Female Labor Force Participation Rate
# No
# 4                                    67.1
# ...

# %%
train.tail()
# Out:
#          Country Level of development European Union Membership  \
# No
# 48  Saudi Arabia           Developing                Not Member
# 57      Thailand           Developing                Not Member
# 58       Tunisia           Developing                Not Member
# 59        Turkey           Developing                Not Member
# 60       Uruguay           Developing                Not Member
#
#              Currency  Women Entrepreneurship Index  Entrepreneurship Index  \
# No
# 48  National Currency                          37.0                    49.6
# 57  National Currency                          36.6                    32.1
# 58  National Currency                          30.7                    35.5
# 59  National Currency                          39.3                    54.6
# 60  National Currency                          44.5                    41.4
#
#     Inflation rate  Female Labor Force Participation Rate
# No
# ...

# %%
train.plot(x='Country',y='Inflation rate',kind='barh',figsize=(10,20))
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
train.describe()
# Out:
#        Women Entrepreneurship Index  Entrepreneurship Index  Inflation rate  \
# count                     51.000000               51.000000       51.000000
# mean                      47.835294               47.241176        2.587647
# std                       14.268480               16.193149        5.380639
# min                       25.300000               24.800000       -2.250000
# 25%                       36.350000               31.900000       -0.500000
# 50%                       44.500000               42.700000        0.600000
# 75%                       59.150000               65.400000        3.600000
# max                       74.800000               77.600000       26.500000
#
#        Female Labor Force Participation Rate
# count                              51.000000
# mean                               58.481765
# std                                13.864567
# min                                13.000000
# 25%                                55.800000
# ...

# %%
print("count of samples and features: ", train.shape)
print("Are there missing values: ",train.isnull().values.any())
# Out:
# count of samples and features:  (51, 8)
# Are there missing values:  False

# %%
train['Level of development'].value_counts()
# Out:
# Developed     27
# Developing    24
# Name: Level of development, dtype: int64

# %%
developed_countries_wei=train[train['Level of development']=="Developed"]

# %%
Developing_countries_wei=train[train['Level of development']=="Developing"]

# %%
Developing_countries_wei.plot(x='Country',y='Inflation rate',kind='barh',figsize=(5,5),title="Inflation Rate w.r.t Developing Countries")
# Out:
# <AxesSubplot:title={'center':'Inflation Rate w.r.t Developing Countries'}, ylabel='Country'>

# %%
fig=developed_countries_wei.plot(x='Country',y='Inflation rate',kind='barh',figsize=(5,5),title="Inflation Rate w.r.t Developed Countries")

# %%
train['Currency'].value_counts()
# Out:
# National Currency    36
# Euro                 15
# Name: Currency, dtype: int64

# %%
train.plot(y='Women Entrepreneurship Index',x='Country',figsize=(10,20),kind='barh')
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
train['Women Entrepreneurship Index'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>
